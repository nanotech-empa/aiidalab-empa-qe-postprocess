# %% [markdown]
# # Search QE Post-processing Calculations
#
# Find completed or running QE BandUPpy unfolding workflows and open the viewer for a finished workflow PK.

# %%
from aiida import load_profile

try:
    load_profile()
except Exception:
    pass

from empa_qe_postprocess.unfolding import display_search_widget

search = display_search_widget()
