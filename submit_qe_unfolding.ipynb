# %% [markdown]
# # Submit QE Band Unfolding
#
# Prepare a folded-kpoints Quantum ESPRESSO bands calculation for BandUPpy unfolding. This notebook only submits or tracks the post-processing input calculation; use the viewer notebook for unfolding and plotting.

# %%
from aiida import load_profile

try:
    load_profile()
except Exception:
    pass

from empa_qe_postprocess.unfolding import display_submission_widget

submission = display_submission_widget()
